# %% [markdown]
# # Import Packages:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# import dash
# from dash import dcc
# from dash import html
# from dash.dependencies import Input, Output, State
import plotly.express as px

# %%
# Co2 dataset
df_co2 = pd.read_csv('Data/gapminder/consumption_co2_emissions_1000_tonnes.csv')
# Continent dataset
df_cont = pd.read_csv('Data/Countries-Continents.csv')

# %%
df_co2.head()
# Out:
#                 country   1990   1991   1992   1993   1994   1995   1996  \
# 0               Albania   5620   4570   2840   2630   2290   2460   2870
# 1  United Arab Emirates  55.2k    61k  63.5k  68.3k  75.2k  75.2k  78.1k
# 2             Argentina   105k   113k   118k   116k   120k   122k   130k
# 3               Armenia  13.7k  13.4k   4120   1990   1940   2840   3090
# 4             Australia   235k   233k   236k   237k   244k   250k   253k
#
#     1997  1998  ...  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0   2190  2510  ...  6130  6370  6140  6350  6060  5870  6300  5660  5500
# 1  78.9k   92k  ...  244k  200k  195k  217k  238k  245k  255k  230k  234k
# 2   136k  138k  ...  177k  165k  177k  185k  187k  193k  197k  203k  200k
# 3   4120  4240  ...  6500  5930  5540  5730  6330  6170  6120  5630  5700
# 4   262k  276k  ...  367k  376k  384k  391k  401k  382k  375k  373k  373k
#
#    2017
# 0  5650
# 1  236k
# 2  202k
# 3  5560
# 4  379k
#
# [5 rows x 29 columns]

# %% [markdown]
# # Reshaping co2 dataframe

# %%
df_co2 = df_co2.melt(id_vars='country')
df_co2.columns = ['Country', 'Year', 'Co2_Emission']
df_co2.head()
# Out:
#                 Country  Year Co2_Emission
# 0               Albania  1990         5620
# 1  United Arab Emirates  1990        55.2k
# 2             Argentina  1990         105k
# 3               Armenia  1990        13.7k
# 4             Australia  1990         235k

# %% [markdown]
# # Merging Continent dataset

# %%
df = df_co2.merge(df_cont, on='Country', how='left')
df.head()
# Out:
#                 Country  Year Co2_Emission      Continent
# 0               Albania  1990         5620         Europe
# 1  United Arab Emirates  1990        55.2k           Asia
# 2             Argentina  1990         105k  South America
# 3               Armenia  1990        13.7k         Europe
# 4             Australia  1990         235k        Oceania

# %% [markdown]
# # Fixing NaNs by hand:

# %%
df.loc[df.Country == 'Burkina Faso', 'Continent'] = 'Africa'

# %%
df.loc[df.Country == "Cote d'Ivoire", 'Continent'] = 'Africa'

# %%
df.loc[df.Country == "Czech Republic", 'Continent'] = 'Europe'

# %%
df.loc[df.Country == "Hong Kong, China", 'Continent'] = 'Asia'

# %%
df.loc[df.Country == "Kyrgyz Republic", 'Continent'] = 'Asia'

# %%
df.loc[df.Country == "South Korea", 'Continent'] = 'Asia'

# %%
df.loc[df.Country == "Lao", 'Continent'] = 'Asia'

# %%
df.loc[df.Country == "Russia", 'Continent'] = 'Asia'

# %%
df.loc[df.Country == "Slovak Republic", 'Continent'] = 'Europe'

# %%
df.loc[df.Country == "Taiwan", 'Continent'] = 'Asia'

# %%
df.loc[df.Country == "United States", 'Continent'] = 'North America'

# %%
df[df.Continent.isna()]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Co2_Emission, Continent]
# Index: []

# %% [markdown]
# # Fixing Columns data types:

# %%
df = df.astype({'Year':'int32'})

# %%
def fix_col(s):
    if 'k' in s:
        return float(s[:-1]) *1000
    elif 'M' in s:
        return float(s[:-1]) *1000000
    return float(s)

# %%
df['Co2_Emission'] = df['Co2_Emission'].apply(fix_col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3332 entries, 0 to 3331
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       3332 non-null   object
#  1   Year          3332 non-null   int32
#  2   Co2_Emission  3332 non-null   float64
#  3   Continent     3332 non-null   object
# dtypes: float64(1), int32(1), object(2)
# memory usage: 117.1+ KB

# %% [markdown]
# # Writing new cvs file:

# %%
df.to_csv('Data/co2.csv', index=False)

# %%
df_co = pd.read_csv('Data/co2.csv')
df_co.head()
# Out:
#                 Country  Year  Co2_Emission      Continent
# 0               Albania  1990        5620.0         Europe
# 1  United Arab Emirates  1990       55200.0           Asia
# 2             Argentina  1990      105000.0  South America
# 3               Armenia  1990       13700.0         Europe
# 4             Australia  1990      235000.0        Oceania

# %%
df_co.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3332 entries, 0 to 3331
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       3332 non-null   object
#  1   Year          3332 non-null   int64
#  2   Co2_Emission  3332 non-null   float64
#  3   Continent     3332 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 104.2+ KB

# %% [markdown]
# # Visuals

# %%
px.bar(df_co, x='Country', 
          y='Co2_Emission', 
          title='Life Expectancy for different gdp per capita', 
          animation_frame='Year',
          template='seaborn',
          hover_name='Country')
# Out:
# <div>                            <div id="8f74d864-20ed-474b-88a4-80fbd5a85e15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f74d864-20ed-474b-88a4-80fbd5a85e15")) {                    Plotly.newPlot(                        "8f74d864-20ed-474b-88a4-80fbd5a85e15",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Year=1990<br>Country=%{x}<br>Co2_Emission=%{y}<extra></extra>","hovertext":["Albania","United Arab Emirates","Argentina","Armenia","Australia","Austria","Azerbaijan","Belgium","Benin","Burkina Faso","Bangladesh","Bulgaria","Bahrain","Belarus","Bolivia","Brazil","Brunei","Botswana","Canada","Switzerland","Chile","China","Cote d'Ivoire","Cameroon","Colombia","Costa Rica","Cyprus","Czech Republic","Germany","Denmark","Dominican Republic","Ecuador","Egypt","Spain","Estonia","Ethiopia","Finland","France","United Kingdom","Georgia","Ghana","Guinea","Greece","Guatemala","Hong Kong, China","Honduras","Croatia","Hungary","Indonesia","India","Ireland","Iran","Israel","Italy","Jamaica","Jordan","Japan","Kazakhstan","Kenya","Kyrgyz Republic","Cambodia","South Korea","Kuwait","Lao","Sri Lanka","Lithuania","Luxembourg","Latvia","Morocco","Madagascar","Mexico","Malta","Mongolia","Mozambique","Mauritius","Malawi","Malaysia","Namibia","Nigeria","Nicaragua","Netherlands","Norway","Nepal","New Zealand","Oman","Pakistan","Panama","Peru","Philippines","Poland","Portugal","Paraguay","Qatar","Romania","Russia","Rwanda","Saudi Arabia","Senegal","Singapore","El Salvador","Slovak Republic","Slovenia","Sweden","Togo","Thailand","Trinidad and Tobago","Tunisia","Turkey","Taiwan","Tanzania","Uganda","Ukraine","Uruguay","United States","Venezuela","Vietnam","South Africa","Zambia","Zimbabwe"],"legendgroup":"","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Albania","United Arab Emirates","Argentina","Armenia","Australia","Austria","Azerbaijan","Belgium","Benin","Burkina Faso","Bangladesh","Bulgaria","Bahrain","Belarus","Bolivia","Brazil","Brunei","Botswana","Canada","Switzerland","Chile","China","Cote d'Ivoire","Cameroon","Colombia","Costa Rica","Cyprus","Czech Republic","Germany","Denmark","Dominican Republic","Ecuador","Egypt","Spain","Estonia","Ethiopia","Finland","France","United Kingdom","Georgia","Ghana","Guinea","Greece","Guatemala","Hong Kong, China","Honduras","Croatia","Hungary","Indonesia","India","Ireland","Iran","Israel","Italy","Jamaica","Jordan","Japan","Kazakhstan","Kenya","Kyrgyz Republic","Cambodia","South Korea","Kuwait","Lao","Sri Lanka","Lithuania","Luxembourg","Latvia","Morocco","Madagascar","Mexico","Malta","Mongolia","Mozambique","Mauritius","Malawi","Malaysia","Namibia","Nigeria","Nicaragua","Netherlands","Norway","Nepal","New Zealand","Oman","Pakistan","Panama","Peru","Philippines","Poland","Portugal","Paraguay","Qatar","Romania","Russia","Rwanda","Saudi Arabia","Senegal","Singapore","El Salvador","Slovak Republic","Slovenia","Sweden","Togo","Thailand","Tr
],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"<b>%{hovertext}</b><br><br>labels=%{label}<br>Co2_Emission_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>Co2_Emission=%{color}<extra></extra>","hovertext":["Albania","Argentina","Armenia","Australia","Austria","Azerbaijan","Bahrain","Bangladesh","Belarus","Belgium","Benin","Bolivia","Botswana","Brazil","Brunei","Bulgaria","Burkina Faso","Cambodia","Cameroon","Canada","Chile","China","Colombia","Costa Rica","Cote d'Ivoire","Croatia","Cyprus","Czech Republic","Denmark","Dominican Republic","Ecuador","Egypt","El Salvador","Estonia","Ethiopia","Finland","France","Georgia","Germany","Ghana","Greece","Guatemala","Guinea","Honduras","Hong Kong, China","Hungary","India","Indonesia","Iran","Ireland","Israel","Italy","Jamaica","Japan","Jordan","Kazakhstan","Kenya","Kuwait","Kyrgyz Republic","Lao","Latvia","Lithuania","Luxembourg","Madag ...

# %%
df_co.groupby(['Year']).mean().reset_index()
# Out:
#     Year   Co2_Emission
# 0   1990  181215.638655
# 1   1991  181613.109244
# 2   1992  179476.042017
# 3   1993  181717.722689
# 4   1994  182697.386555
# 5   1995  186751.747899
# 6   1996  192161.722689
# 7   1997  193003.546218
# 8   1998  191493.042017
# 9   1999  194454.394958
# 10  2000  200099.579832
# 11  2001  201608.504202
# 12  2002  206154.033613
# 13  2003  215422.932773
# 14  2004  225353.159664
# 15  2005  232865.075630
# 16  2006  240462.705882
# 17  2007  247435.403361
# 18  2008  252721.915966
# 19  2009  249085.873950
# 20  2010  262017.092437
# 21  2011  271257.126050
# 22  2012  275571.084034
# 23  2013  276591.117647
# 24  2014  278516.831933
# 25  2015  278360.563025
# 26  2016  279094.033613
# 27  2017  282400.840336

# %%
px.line(df_co.groupby(['Year']).mean().reset_index(), x="Year", y="Co2_Emission", title='Co2_Emission mean')
# Out:
# <div>                            <div id="ba39783d-559d-4eba-a0d0-b2d025d60d49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba39783d-559d-4eba-a0d0-b2d025d60d49")) {                    Plotly.newPlot(                        "ba39783d-559d-4eba-a0d0-b2d025d60d49",                        [{"hovertemplate":"Year=%{x}<br>Co2_Emission=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[181215.6386554622,181613.1092436975,179476.04201680672,181717.72268907563,182697.38655462186,186751.74789915967,192161.72268907563,193003.5462184874,191493.04201680672,194454.3949579832,200099.57983193276,201608.50420168068,206154.03361344538,215422.93277310923,225353.15966386555,232865.0756302521,240462.70588235295,247435.40336134454,252721.91596638656,249085.87394957984,262017.09243697478,271257.12605042016,275571.08403361344,276591.1176470588,278516.8319327731,278360.5630252101,279094.03361344535,282400.8403361345],"yaxis":"y"}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22 ...

# %%
px.line(df_co[df_co['Country']=='Egypt'], x="Year", y="Co2_Emission", title='Co2_Emission mean')

# %%
ddd = df_co.groupby(['Continent', 'Year']).mean().reset_index()
px.line(ddd[ddd['Continent']=='Africa'],
                        x="Year", 
                        y="Co2_Emission", 
                        title='Global Co2_Emission mean')
# Out:
# <div>                            <div id="8dafdcac-a78f-4bf6-b6f9-4b6ddd0e5334" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8dafdcac-a78f-4bf6-b6f9-4b6ddd0e5334")) {                    Plotly.newPlot(                        "8dafdcac-a78f-4bf6-b6f9-4b6ddd0e5334",                        [{"hovertemplate":"Year=%{x}<br>Co2_Emission=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[16924.0,17925.5,17319.346153846152,18150.5,18414.96153846154,19269.153846153848,19267.115384615383,20403.53846153846,20990.846153846152,21955.884615384617,23572.30769230769,23697.0,23500.0,25698.423076923078,27105.23076923077,27817.115384615383,28785.576923076922,30717.03846153846,32503.0,33156.5,32965.92307692308,34636.07692307692,35281.88461538462,37089.730769230766,38782.03846153846,37916.42307692308,38761.153846153844,38574.230769230766],"yaxis":"y"}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444," ...
